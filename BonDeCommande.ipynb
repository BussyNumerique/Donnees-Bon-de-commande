# %% [markdown]
# # Exercice * : données csv en table
#
# Un bon de commande a été réalisé sur tableur :
# ![boncde%20image.PNG](attachment:boncde%20image.PNG)
#
# Vous devez executer le code ci-dessous afin de récupérer les données du fichier csv.

# %%
import csv # le module pour les fichiers csv
file = open("boncde.csv" , "r") # ouvrir le fichier
csv_en_dico = csv.DictReader(file , delimiter = ";") # initialisation d’un lecteur de fichier avec création automatique de dictionnaire

for ligne in csv_en_dico : # parcours du lecteur avec une boucle
	print(dict(ligne)) # affichage ligne à ligne
file.close () # fermeture du fichier

# %% [markdown]
# 1 - Compléter la fonction ci-dessous qui s'assure que la commande est valide, c'est à dire que les quantités saisies dans la commande sont positives.

# %%
def verificationqte(dico):
    pass

# %% [markdown]
# 2 - Compléter la fonction ci-dessous qui renvoie le prix total de la commande.
# Le prix dans le fichier tableur est le prix unitaire.

# %%
def prix(dico):
    pass
